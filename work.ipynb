# %%
import numpy as np
from os import mkdir
from time import sleep
from urllib.request import urlretrieve as src_to_jpg

from sys import path
path.append('/home/np_1961/parser/utils/')
from browser import turn_on_the_browser as return_driver
from browser import By
from browser import scrollin
from browser import Keys
from browser import ActionChains
from browser import UserAgent
from File_workers import file_workers
from Norm_generate import get_random_url
from Terminal import terminal_write

from ALIBABA_PARSER import Parser

# %%
Parser(search=False)
# Out:
# ---create new folder name ---> 556
# ------download photo ---> 7
# ---------------------------------------------------------------------------
# FileExistsError                           Traceback (most recent call last)
# ~/parser/ALIBABA_PARSER.py in photo_downloader(self, link_quantity, new_folder_name, file_path)
#     101
# --> 102
#     103
#
# FileExistsError: [Errno 17] File exists: 'pictures/0'
#
# During handling of the above exception, another exception occurred:
#
# FileExistsError                           Traceback (most recent call last)
# ~/parser/ALIBABA_PARSER.py in photo_downloader(self, link_quantity, new_folder_name, file_path)
#     101
# --> 102
#     103
#
# FileExistsError: [Errno 17] File exists: 'pictures/1'
#
# During handling of the above exception, another exception occurred:
#
# FileExistsError                           Traceback (most recent call last)
# ~/parser/ALIBABA_PARSER.py in photo_downloader(self, link_quantity, new_folder_name, file_path)
#     101
# --> 102
#     103
#
# FileExistsError: [Errno 17] File exists: 'pictures/2'
#
# During handling of the above exception, another exception occurred:
#
# FileExistsError                           Traceback (most recent call last)
# ~/parser/ALIBABA_PARSER.py in photo_downloader(self, link_quantity, new_folder_name, file_path)
#     101
# --> 102
#     103
#
# FileExistsError: [Errno 17] File exists: 'pictures/3'
#
# During handling of the above exception, another exception occurred:
#
# FileExistsError                           Traceback (most recent call last)
# ~/parser/ALIBABA_PARSER.py in photo_downloader(self, link_quantity, new_folder_name, file_path)
#     101
# --> 102
#     103
#
# FileExistsError: [Errno 17] File exists: 'pictures/4'
#
# During handling of the above exception, another exception occurred:
#
# FileExistsError                           Traceback (most recent call last)
# ~/parser/ALIBABA_PARSER.py in photo_downloader(self, link_quantity, new_folder_name, file_path)
#     101
# --> 102
#     103
#
# FileExistsError: [Errno 17] File exists: 'pictures/5'
#
# During handling of the above exception, another exception occurred:
#
# FileExistsError                           Traceback (most recent call last)
# ~/parser/ALIBABA_PARSER.py in photo_downloader(self, link_quantity, new_folder_name, file_path)
#     101
# --> 102
#     103
#
# FileExistsError: [Errno 17] File exists: 'pictures/6'
#
# During handling of the above exception, another exception occurred:
#
# FileExistsError                           Traceback (most recent call last)
# ~/parser/ALIBABA_PARSER.py in photo_downloader(self, link_quantity, new_folder_name, file_path)
#     101
# --> 102
#     103
#
# FileExistsError: [Errno 17] File exists: 'pictures/7'
#
# During handling of the above exception, another exception occurred:
#
# FileExistsError                           Traceback (most recent call last)
# ~/parser/ALIBABA_PARSER.py in photo_downloader(self, link_quantity, new_folder_name, file_path)
#     101
# --> 102
#     103
#
# FileExistsError: [Errno 17] File exists: 'pictures/8'
#
# During handling of the above exception, another exception occurred:
#
# FileExistsError                           Traceback (most recent call last)
# ~/parser/ALIBABA_PARSER.py in photo_downloader(self, link_quantity, new_folder_name, file_path)
#     101
# --> 102
#     103
#
# FileExistsError: [Errno 17] File exists: 'pictures/9'
#
# During handling of the above exception, another exception occurred:
#
# FileExistsError                           Traceback (most recent call last)
# ~/parser/ALIBABA_PARSER.py in photo_downloader(self, link_quantity, new_folder_name, file_path)
#     101
# --> 102
#     103
#
# FileExistsError: [Errno 17] File exists: 'pictures/10'
#
# During handling of the above exception, another exception occurred:
#
# FileExistsError                           Traceback (most recent call last)
# ~/parser/ALIBABA_PARSER.py in photo_downloader(self, link_quantity, new_folder_name, file_path)
#     101
# --> 102
#     103
#
# FileExistsError: [Errno 17] File exists: 'pictures/11'
#
# During handling of the above exception, another exception occurred:
#
# FileExistsError                           Traceback (most recent call last)
# ~/parser/ALIBABA_PARSER.py in photo_downloader(self, link_quantity, new_folder_name, file_path)
#     101
# --> 102
#     103
#
# FileExistsError: [Errno 17] File exists: 'pictures/12'
#
# During handling of the above exception, another exception occurred:
#
# FileExistsError                           Traceback (most recent call last)
# ~/parser/ALIBABA_PARSER.py in photo_downloader(self, link_quantity, new_folder_name, file_path)
#     101
# --> 102
#     103
#
# FileExistsError: [Errno 17] File exists: 'pictures/13'
#
# During handling of the above exception, another exception occurred:
#
# FileExistsError                           Traceback (most recent call last)
# ~/parser/ALIBABA_PARSER.py in photo_downloader(self, link_quantity, new_folder_name, file_path)
#     101
# --> 102
#     103
#
# FileExistsError: [Errno 17] File exists: 'pictures/14'
#
# During handling of the above exception, another exception occurred:
#
# FileExistsError                           Traceback (most recent call last)
# ~/parser/ALIBABA_PARSER.py in photo_downloader(self, link_quantity, new_folder_name, file_path)
#     101
# --> 102
#     103
#
# FileExistsError: [Errno 17] File exists: 'pictures/15'
#
# During handling of the above exception, another exception occurred:
#
# FileExistsError                           Traceback (most recent call last)
# ~/parser/ALIBABA_PARSER.py in photo_downloader(self, link_quantity, new_folder_name, file_path)
#     101
# --> 102
#     103
#
# FileExistsError: [Errno 17] File exists: 'pictures/16'
#
# During handling of the above exception, another exception occurred:
#
# FileExistsError                           Traceback (most recent call last)
# ~/parser/ALIBABA_PARSER.py in photo_downloader(self, link_quantity, new_folder_name, file_path)
#     101
# --> 102
#     103
#
# FileExistsError: [Errno 17] File exists: 'pictures/17'
#
# During handling of the above exception, another exception occurred:
#
# FileExistsError                           Traceback (most recent call last)
# ~/parser/ALIBABA_PARSER.py in photo_downloader(self, link_quantity, new_folder_name, file_path)
#     101
# --> 102
#     103
#
# FileExistsError: [Errno 17] File exists: 'pictures/18'
#
# During handling of the above exception, another exception occurred:
#
# FileExistsError                           Traceback (most recent call last)
# ~/parser/ALIBABA_PARSER.py in photo_downloader(self, link_quantity, new_folder_name, file_path)
#     101
# --> 102
#     103
#
# FileExistsError: [Errno 17] File exists: 'pictures/19'
#
# During handling of the above exception, another exception occurred:
#
# FileExistsError                           Traceback (most recent call last)
# ~/parser/ALIBABA_PARSER.py in photo_downloader(self, link_quantity, new_folder_name, file_path)
#     101
# --> 102
#     103
#
# FileExistsError: [Errno 17] File exists: 'pictures/20'
#
# During handling of the above exception, another exception occurred:
#
# FileExistsError                           Traceback (most recent call last)
# ~/parser/ALIBABA_PARSER.py in photo_downloader(self, link_quantity, new_folder_name, file_path)
#     101
# --> 102
#     103
#
# FileExistsError: [Errno 17] File exists: 'pictures/21'
#
# During handling of the above exception, another exception occurred:
#
# FileExistsError                           Traceback (most recent call last)
# ~/parser/ALIBABA_PARSER.py in photo_downloader(self, link_quantity, new_folder_name, file_path)
#     101
# --> 102
#     103
#
# FileExistsError: [Errno 17] File exists: 'pictures/22'
#
# During handling of the above exception, another exception occurred:
#
# FileExistsError                           Traceback (most recent call last)
# ~/parser/ALIBABA_PARSER.py in photo_downloader(self, link_quantity, new_folder_name, file_path)
#     101
# --> 102
#     103
#
# FileExistsError: [Errno 17] File exists: 'pictures/23'
#
# During handling of the above exception, another exception occurred:
#
# FileExistsError                           Traceback (most recent call last)
# ~/parser/ALIBABA_PARSER.py in photo_downloader(self, link_quantity, new_folder_name, file_path)
#     101
# --> 102
#     103
#
# FileExistsError: [Errno 17] File exists: 'pictures/24'
#
# During handling of the above exception, another exception occurred:
#
# FileExistsError                           Traceback (most recent call last)
# ~/parser/ALIBABA_PARSER.py in photo_downloader(self, link_quantity, new_folder_name, file_path)
#     101
# --> 102
#     103
#
# FileExistsError: [Errno 17] File exists: 'pictures/25'
#
# During handling of the above exception, another exception occurred:
#
# FileExistsError                           Traceback (most recent call last)
# ~/parser/ALIBABA_PARSER.py in photo_downloader(self, link_quantity, new_folder_name, file_path)
#     101
# --> 102
#     103
#
# FileExistsError: [Errno 17] File exists: 'pictures/26'
#
# During handling of the above exception, another exception occurred:
#
# FileExistsError                           Traceback (most recent call last)
# ~/parser/ALIBABA_PARSER.py in photo_downloader(self, link_quantity, new_folder_name, file_path)
#     101
# --> 102
#     103
#
# FileExistsError: [Errno 17] File exists: 'pictures/27'
#
# During handling of the above exception, another exception occurred:
#
# FileExistsError                           Traceback (most recent call last)
# ~/parser/ALIBABA_PARSER.py in photo_downloader(self, link_quantity, new_folder_name, file_path)
#     101
# --> 102
#     103
#
# FileExistsError: [Errno 17] File exists: 'pictures/28'
#
# During handling of the above exception, another exception occurred:
#
# FileExistsError                           Traceback (most recent call last)
# ~/parser/ALIBABA_PARSER.py in photo_downloader(self, link_quantity, new_folder_name, file_path)
#     101
# --> 102
#     103
#
# FileExistsError: [Errno 17] File exists: 'pictures/29'
#
# During handling of the above exception, another exception occurred:
#
# FileExistsError                           Traceback (most recent call last)
# ~/parser/ALIBABA_PARSER.py in photo_downloader(self, link_quantity, new_folder_name, file_path)
#     101
# --> 102
#     103
#
# FileExistsError: [Errno 17] File exists: 'pictures/30'
#
# During handling of the above exception, another exception occurred:
#
# FileExistsError                           Traceback (most recent call last)
# ~/parser/ALIBABA_PARSER.py in photo_downloader(self, link_quantity, new_folder_name, file_path)
#     101
# --> 102
#     103
#
# FileExistsError: [Errno 17] File exists: 'pictures/31'
#
# During handling of the above exception, another exception occurred:
#
# FileExistsError                           Traceback (most recent call last)
# ~/parser/ALIBABA_PARSER.py in photo_downloader(self, link_quantity, new_folder_name, file_path)
#     101
# --> 102
#     103
#
# FileExistsError: [Errno 17] File exists: 'pictures/32'
#
# During handling of the above exception, another exception occurred:
#
# FileExistsError                           Traceback (most recent call last)
# ~/parser/ALIBABA_PARSER.py in photo_downloader(self, link_quantity, new_folder_name, file_path)
#     101
# --> 102
#     103
#
# FileExistsError: [Errno 17] File exists: 'pictures/33'
#
# During handling of the above exception, another exception occurred:
#
# FileExistsError                           Traceback (most recent call last)
# ~/parser/ALIBABA_PARSER.py in photo_downloader(self, link_quantity, new_folder_name, file_path)
#     101
# --> 102
#     103
#
# FileExistsError: [Errno 17] File exists: 'pictures/34'
#
# During handling of the above exception, another exception occurred:
#
# FileExistsError                           Traceback (most recent call last)
# ~/parser/ALIBABA_PARSER.py in photo_downloader(self, link_quantity, new_folder_name, file_path)
#     101
# --> 102
#     103
#
# FileExistsError: [Errno 17] File exists: 'pictures/35'
#
# During handling of the above exception, another exception occurred:
#
# FileExistsError                           Traceback (most recent call last)
# ~/parser/ALIBABA_PARSER.py in photo_downloader(self, link_quantity, new_folder_name, file_path)
#     101
# --> 102
#     103
#
# FileExistsError: [Errno 17] File exists: 'pictures/36'
#
# During handling of the above exception, another exception occurred:
#
# FileExistsError                           Traceback (most recent call last)
# ~/parser/ALIBABA_PARSER.py in photo_downloader(self, link_quantity, new_folder_name, file_path)
#     101
# --> 102
#     103
#
# FileExistsError: [Errno 17] File exists: 'pictures/37'
#
# During handling of the above exception, another exception occurred:
#
# FileExistsError                           Traceback (most recent call last)
# ~/parser/ALIBABA_PARSER.py in photo_downloader(self, link_quantity, new_folder_name, file_path)
#     101
# --> 102
#     103
#
# FileExistsError: [Errno 17] File exists: 'pictures/38'
#
# During handling of the above exception, another exception occurred:
#
# FileExistsError                           Traceback (most recent call last)
# ~/parser/ALIBABA_PARSER.py in photo_downloader(self, link_quantity, new_folder_name, file_path)
#     101
# --> 102
#     103
#
# FileExistsError: [Errno 17] File exists: 'pictures/39'
#
# During handling of the above exception, another exception occurred:
#
# FileExistsError                           Traceback (most recent call last)
# ~/parser/ALIBABA_PARSER.py in photo_downloader(self, link_quantity, new_folder_name, file_path)
#     101
# --> 102
#     103
#
# FileExistsError: [Errno 17] File exists: 'pictures/40'
#
# During handling of the above exception, another exception occurred:
#
# FileExistsError                           Traceback (most recent call last)
# ~/parser/ALIBABA_PARSER.py in photo_downloader(self, link_quantity, new_folder_name, file_path)
#     101
# --> 102
#     103
#
# FileExistsError: [Errno 17] File exists: 'pictures/41'
#
# During handling of the above exception, another exception occurred:
#
# FileExistsError                           Traceback (most recent call last)
# ~/parser/ALIBABA_PARSER.py in photo_downloader(self, link_quantity, new_folder_name, file_path)
#     101
# --> 102
#     103
#
# FileExistsError: [Errno 17] File exists: 'pictures/42'
#
# During handling of the above exception, another exception occurred:
#
# FileExistsError                           Traceback (most recent call last)
# ~/parser/ALIBABA_PARSER.py in photo_downloader(self, link_quantity, new_folder_name, file_path)
#     101
# --> 102
#     103
#
# FileExistsError: [Errno 17] File exists: 'pictures/43'
#
# During handling of the above exception, another exception occurred:
#
# FileExistsError                           Traceback (most recent call last)
# ~/parser/ALIBABA_PARSER.py in photo_downloader(self, link_quantity, new_folder_name, file_path)
#     101
# --> 102
#     103
#
# FileExistsError: [Errno 17] File exists: 'pictures/44'
#
# During handling of the above exception, another exception occurred:
#
# FileExistsError                           Traceback (most recent call last)
# ~/parser/ALIBABA_PARSER.py in photo_downloader(self, link_quantity, new_folder_name, file_path)
#     101
# --> 102
#     103
#
# FileExistsError: [Errno 17] File exists: 'pictures/45'
#
# During handling of the above exception, another exception occurred:
#
# FileExistsError                           Traceback (most recent call last)
# ~/parser/ALIBABA_PARSER.py in photo_downloader(self, link_quantity, new_folder_name, file_path)
#     101
# --> 102
#     103
#
# FileExistsError: [Errno 17] File exists: 'pictures/46'
#
# During handling of the above exception, another exception occurred:
#
# FileExistsError                           Traceback (most recent call last)
# ~/parser/ALIBABA_PARSER.py in photo_downloader(self, link_quantity, new_folder_name, file_path)
#     101
# --> 102
#     103
#
# FileExistsError: [Errno 17] File exists: 'pictures/47'
#
# During handling of the above exception, another exception occurred:
#
# FileExistsError                           Traceback (most recent call last)
# ~/parser/ALIBABA_PARSER.py in photo_downloader(self, link_quantity, new_folder_name, file_path)
#     101
# --> 102
#     103
#
# FileExistsError: [Errno 17] File exists: 'pictures/48'
#
# During handling of the above exception, another exception occurred:
#
# FileExistsError                           Traceback (most recent call last)
# ~/parser/ALIBABA_PARSER.py in photo_downloader(self, link_quantity, new_folder_name, file_path)
#     101
# --> 102
#     103
#
# FileExistsError: [Errno 17] File exists: 'pictures/49'
#
# During handling of the above exception, another exception occurred:
#
# FileExistsError                           Traceback (most recent call last)
# ~/parser/ALIBABA_PARSER.py in photo_downloader(self, link_quantity, new_folder_name, file_path)
#     101
# --> 102
#     103
#
# FileExistsError: [Errno 17] File exists: 'pictures/50'
#
# During handling of the above exception, another exception occurred:
#
# FileExistsError                           Traceback (most recent call last)
# ~/parser/ALIBABA_PARSER.py in photo_downloader(self, link_quantity, new_folder_name, file_path)
#     101
# --> 102
#     103
#
# FileExistsError: [Errno 17] File exists: 'pictures/51'
#
# During handling of the above exception, another exception occurred:
#
# FileExistsError                           Traceback (most recent call last)
# ~/parser/ALIBABA_PARSER.py in photo_downloader(self, link_quantity, new_folder_name, file_path)
#     101
# --> 102
#     103
#
# FileExistsError: [Errno 17] File exists: 'pictures/52'
#
# During handling of the above exception, another exception occurred:
#
# FileExistsError                           Traceback (most recent call last)
# ~/parser/ALIBABA_PARSER.py in photo_downloader(self, link_quantity, new_folder_name, file_path)
#     101
# --> 102
#     103
#
# FileExistsError: [Errno 17] File exists: 'pictures/53'
#
# During handling of the above exception, another exception occurred:
#
# FileExistsError                           Traceback (most recent call last)
# ~/parser/ALIBABA_PARSER.py in photo_downloader(self, link_quantity, new_folder_name, file_path)
#     101
# --> 102
#     103
#
# FileExistsError: [Errno 17] File exists: 'pictures/54'
#
# During handling of the above exception, another exception occurred:
#
# FileExistsError                           Traceback (most recent call last)
# ~/parser/ALIBABA_PARSER.py in photo_downloader(self, link_quantity, new_folder_name, file_path)
#     101
# --> 102
#     103
#
# FileExistsError: [Errno 17] File exists: 'pictures/55'
#
# During handling of the above exception, another exception occurred:
#
# FileExistsError                           Traceback (most recent call last)
# ~/parser/ALIBABA_PARSER.py in photo_downloader(self, link_quantity, new_folder_name, file_path)
#     101
# --> 102
#     103
#
# FileExistsError: [Errno 17] File exists: 'pictures/56'
#
# During handling of the above exception, another exception occurred:
#
# FileExistsError                           Traceback (most recent call last)
# ~/parser/ALIBABA_PARSER.py in photo_downloader(self, link_quantity, new_folder_name, file_path)
#     101
# --> 102
#     103
#
# FileExistsError: [Errno 17] File exists: 'pictures/57'
#
# During handling of the above exception, another exception occurred:
#
# FileExistsError                           Traceback (most recent call last)
# ~/parser/ALIBABA_PARSER.py in photo_downloader(self, link_quantity, new_folder_name, file_path)
#     101
# --> 102
#     103
#
# FileExistsError: [Errno 17] File exists: 'pictures/58'
#
# During handling of the above exception, another exception occurred:
#
# FileExistsError                           Traceback (most recent call last)
# ~/parser/ALIBABA_PARSER.py in photo_downloader(self, link_quantity, new_folder_name, file_path)
#     101
# --> 102
#     103
#
# FileExistsError: [Errno 17] File exists: 'pictures/59'
#
# During handling of the above exception, another exception occurred:
#
# FileExistsError                           Traceback (most recent call last)
# ~/parser/ALIBABA_PARSER.py in photo_downloader(self, link_quantity, new_folder_name, file_path)
#     101
# --> 102
#     103
#
# FileExistsError: [Errno 17] File exists: 'pictures/60'
#
# During handling of the above exception, another exception occurred:
#
# FileExistsError                           Traceback (most recent call last)
# ~/parser/ALIBABA_PARSER.py in photo_downloader(self, link_quantity, new_folder_name, file_path)
#     101
# --> 102
#     103
#
# FileExistsError: [Errno 17] File exists: 'pictures/61'
#
# During handling of the above exception, another exception occurred:
#
# FileExistsError                           Traceback (most recent call last)
# ~/parser/ALIBABA_PARSER.py in photo_downloader(self, link_quantity, new_folder_name, file_path)
#     101
# --> 102
#     103
#
# FileExistsError: [Errno 17] File exists: 'pictures/62'
#
# During handling of the above exception, another exception occurred:
#
# FileExistsError                           Traceback (most recent call last)
# ~/parser/ALIBABA_PARSER.py in photo_downloader(self, link_quantity, new_folder_name, file_path)
#     101
# --> 102
#     103
#
# FileExistsError: [Errno 17] File exists: 'pictures/63'
#
# During handling of the above exception, another exception occurred:
#
# FileExistsError                           Traceback (most recent call last)
# ~/parser/ALIBABA_PARSER.py in photo_downloader(self, link_quantity, new_folder_name, file_path)
#     101
# --> 102
#     103
#
# FileExistsError: [Errno 17] File exists: 'pictures/64'
#
# During handling of the above exception, another exception occurred:
#
# FileExistsError                           Traceback (most recent call last)
# ~/parser/ALIBABA_PARSER.py in photo_downloader(self, link_quantity, new_folder_name, file_path)
#     101
# --> 102
#     103
#
# FileExistsError: [Errno 17] File exists: 'pictures/65'
#
# During handling of the above exception, another exception occurred:
#
# FileExistsError                           Traceback (most recent call last)
# ~/parser/ALIBABA_PARSER.py in photo_downloader(self, link_quantity, new_folder_name, file_path)
#     101
# --> 102
#     103
#
# FileExistsError: [Errno 17] File exists: 'pictures/66'
#
# During handling of the above exception, another exception occurred:
#
# FileExistsError                           Traceback (most recent call last)
# ~/parser/ALIBABA_PARSER.py in photo_downloader(self, link_quantity, new_folder_name, file_path)
#     101
# --> 102
#     103
#
# FileExistsError: [Errno 17] File exists: 'pictures/67'
#
# During handling of the above exception, another exception occurred:
#
# FileExistsError                           Traceback (most recent call last)
# ~/parser/ALIBABA_PARSER.py in photo_downloader(self, link_quantity, new_folder_name, file_path)
#     101
# --> 102
#     103
#
# FileExistsError: [Errno 17] File exists: 'pictures/68'
#
# During handling of the above exception, another exception occurred:
#
# FileExistsError                           Traceback (most recent call last)
# ~/parser/ALIBABA_PARSER.py in photo_downloader(self, link_quantity, new_folder_name, file_path)
#     101
# --> 102
#     103
#
# FileExistsError: [Errno 17] File exists: 'pictures/69'
#
# During handling of the above exception, another exception occurred:
#
# FileExistsError                           Traceback (most recent call last)
# ~/parser/ALIBABA_PARSER.py in photo_downloader(self, link_quantity, new_folder_name, file_path)
#     101
# --> 102
#     103
#
# FileExistsError: [Errno 17] File exists: 'pictures/70'
#
# During handling of the above exception, another exception occurred:
#
# FileExistsError                           Traceback (most recent call last)
# ~/parser/ALIBABA_PARSER.py in photo_downloader(self, link_quantity, new_folder_name, file_path)
#     101
# --> 102
#     103
#
# FileExistsError: [Errno 17] File exists: 'pictures/71'
#
# During handling of the above exception, another exception occurred:
#
# FileExistsError                           Traceback (most recent call last)
# ~/parser/ALIBABA_PARSER.py in photo_downloader(self, link_quantity, new_folder_name, file_path)
#     101
# --> 102
#     103
#
# FileExistsError: [Errno 17] File exists: 'pictures/72'
#
# During handling of the above exception, another exception occurred:
#
# FileExistsError                           Traceback (most recent call last)
# ~/parser/ALIBABA_PARSER.py in photo_downloader(self, link_quantity, new_folder_name, file_path)
#     101
# --> 102
#     103
#
# FileExistsError: [Errno 17] File exists: 'pictures/73'
#
# During handling of the above exception, another exception occurred:
#
# FileExistsError                           Traceback (most recent call last)
# ~/parser/ALIBABA_PARSER.py in photo_downloader(self, link_quantity, new_folder_name, file_path)
#     101
# --> 102
#     103
#
# FileExistsError: [Errno 17] File exists: 'pictures/74'
#
# During handling of the above exception, another exception occurred:
#
# FileExistsError                           Traceback (most recent call last)
# ~/parser/ALIBABA_PARSER.py in photo_downloader(self, link_quantity, new_folder_name, file_path)
#     101
# --> 102
#     103
#
# FileExistsError: [Errno 17] File exists: 'pictures/75'
#
# During handling of the above exception, another exception occurred:
#
# FileExistsError                           Traceback (most recent call last)
# ~/parser/ALIBABA_PARSER.py in photo_downloader(self, link_quantity, new_folder_name, file_path)
#     101
# --> 102
#     103
#
# FileExistsError: [Errno 17] File exists: 'pictures/76'
#
# During handling of the above exception, another exception occurred:
#
# FileExistsError                           Traceback (most recent call last)
# ~/parser/ALIBABA_PARSER.py in photo_downloader(self, link_quantity, new_folder_name, file_path)
#     101
# --> 102
#     103
#
# FileExistsError: [Errno 17] File exists: 'pictures/77'
#
# During handling of the above exception, another exception occurred:
#
# FileExistsError                           Traceback (most recent call last)
# ~/parser/ALIBABA_PARSER.py in photo_downloader(self, link_quantity, new_folder_name, file_path)
#     101
# --> 102
#     103
#
# FileExistsError: [Errno 17] File exists: 'pictures/78'
#
# During handling of the above exception, another exception occurred:
#
# FileExistsError                           Traceback (most recent call last)
# ~/parser/ALIBABA_PARSER.py in photo_downloader(self, link_quantity, new_folder_name, file_path)
#     101
# --> 102
#     103
#
# FileExistsError: [Errno 17] File exists: 'pictures/79'
#
# During handling of the above exception, another exception occurred:
#
# FileExistsError                           Traceback (most recent call last)
# ~/parser/ALIBABA_PARSER.py in photo_downloader(self, link_quantity, new_folder_name, file_path)
#     101
# --> 102
#     103
#
# FileExistsError: [Errno 17] File exists: 'pictures/80'
#
# During handling of the above exception, another exception occurred:
#
# FileExistsError                           Traceback (most recent call last)
# ~/parser/ALIBABA_PARSER.py in photo_downloader(self, link_quantity, new_folder_name, file_path)
#     101
# --> 102
#     103
#
# FileExistsError: [Errno 17] File exists: 'pictures/81'
#
# During handling of the above exception, another exception occurred:
#
# FileExistsError                           Traceback (most recent call last)
# ~/parser/ALIBABA_PARSER.py in photo_downloader(self, link_quantity, new_folder_name, file_path)
#     101
# --> 102
#     103
#
# FileExistsError: [Errno 17] File exists: 'pictures/82'
#
# During handling of the above exception, another exception occurred:
#
# FileExistsError                           Traceback (most recent call last)
# ~/parser/ALIBABA_PARSER.py in photo_downloader(self, link_quantity, new_folder_name, file_path)
#     101
# --> 102
#     103
#
# FileExistsError: [Errno 17] File exists: 'pictures/83'
#
# During handling of the above exception, another exception occurred:
#
# FileExistsError                           Traceback (most recent call last)
# ~/parser/ALIBABA_PARSER.py in photo_downloader(self, link_quantity, new_folder_name, file_path)
#     101
# --> 102
#     103
#
# FileExistsError: [Errno 17] File exists: 'pictures/84'
#
# During handling of the above exception, another exception occurred:
#
# FileExistsError                           Traceback (most recent call last)
# ~/parser/ALIBABA_PARSER.py in photo_downloader(self, link_quantity, new_folder_name, file_path)
#     101
# --> 102
#     103
#
# FileExistsError: [Errno 17] File exists: 'pictures/85'
#
# During handling of the above exception, another exception occurred:
#
# FileExistsError                           Traceback (most recent call last)
# ~/parser/ALIBABA_PARSER.py in photo_downloader(self, link_quantity, new_folder_name, file_path)
#     101
# --> 102
#     103
#
# FileExistsError: [Errno 17] File exists: 'pictures/86'
#
# During handling of the above exception, another exception occurred:
#
# FileExistsError                           Traceback (most recent call last)
# ~/parser/ALIBABA_PARSER.py in photo_downloader(self, link_quantity, new_folder_name, file_path)
#     101
# --> 102
#     103
#
# FileExistsError: [Errno 17] File exists: 'pictures/87'
#
# During handling of the above exception, another exception occurred:
#
# FileExistsError                           Traceback (most recent call last)
# ~/parser/ALIBABA_PARSER.py in photo_downloader(self, link_quantity, new_folder_name, file_path)
#     101
# --> 102
#     103
#
# FileExistsError: [Errno 17] File exists: 'pictures/88'
#
# During handling of the above exception, another exception occurred:
#
# FileExistsError                           Traceback (most recent call last)
# ~/parser/ALIBABA_PARSER.py in photo_downloader(self, link_quantity, new_folder_name, file_path)
#     101
# --> 102
#     103
#
# FileExistsError: [Errno 17] File exists: 'pictures/89'
#
# During handling of the above exception, another exception occurred:
#
# FileExistsError                           Traceback (most recent call last)
# ~/parser/ALIBABA_PARSER.py in photo_downloader(self, link_quantity, new_folder_name, file_path)
#     101
# --> 102
#     103
#
# FileExistsError: [Errno 17] File exists: 'pictures/90'
#
# During handling of the above exception, another exception occurred:
#
# FileExistsError                           Traceback (most recent call last)
# ~/parser/ALIBABA_PARSER.py in photo_downloader(self, link_quantity, new_folder_name, file_path)
#     101
# --> 102
#     103
#
# FileExistsError: [Errno 17] File exists: 'pictures/91'
#
# During handling of the above exception, another exception occurred:
#
# FileExistsError                           Traceback (most recent call last)
# ~/parser/ALIBABA_PARSER.py in photo_downloader(self, link_quantity, new_folder_name, file_path)
#     101
# --> 102
#     103
#
# FileExistsError: [Errno 17] File exists: 'pictures/92'
#
# During handling of the above exception, another exception occurred:
#
# FileExistsError                           Traceback (most recent call last)
# ~/parser/ALIBABA_PARSER.py in photo_downloader(self, link_quantity, new_folder_name, file_path)
#     101
# --> 102
#     103
#
# FileExistsError: [Errno 17] File exists: 'pictures/93'
#
# During handling of the above exception, another exception occurred:
#
# FileExistsError                           Traceback (most recent call last)
# ~/parser/ALIBABA_PARSER.py in photo_downloader(self, link_quantity, new_folder_name, file_path)
#     101
# --> 102
#     103
#
# FileExistsError: [Errno 17] File exists: 'pictures/94'
#
# During handling of the above exception, another exception occurred:
#
# FileExistsError                           Traceback (most recent call last)
# ~/parser/ALIBABA_PARSER.py in photo_downloader(self, link_quantity, new_folder_name, file_path)
#     101
# --> 102
#     103
#
# FileExistsError: [Errno 17] File exists: 'pictures/95'
#
# During handling of the above exception, another exception occurred:
#
# FileExistsError                           Traceback (most recent call last)
# ~/parser/ALIBABA_PARSER.py in photo_downloader(self, link_quantity, new_folder_name, file_path)
#     101
# --> 102
#     103
#
# FileExistsError: [Errno 17] File exists: 'pictures/96'
#
# During handling of the above exception, another exception occurred:
#
# FileExistsError                           Traceback (most recent call last)
# ~/parser/ALIBABA_PARSER.py in photo_downloader(self, link_quantity, new_folder_name, file_path)
#     101
# --> 102
#     103
#
# FileExistsError: [Errno 17] File exists: 'pictures/97'
#
# During handling of the above exception, another exception occurred:
#
# FileExistsError                           Traceback (most recent call last)
# ~/parser/ALIBABA_PARSER.py in photo_downloader(self, link_quantity, new_folder_name, file_path)
#     101
# --> 102
#     103
#
# FileExistsError: [Errno 17] File exists: 'pictures/98'
#
# During handling of the above exception, another exception occurred:
#
# FileExistsError                           Traceback (most recent call last)
# ~/parser/ALIBABA_PARSER.py in photo_downloader(self, link_quantity, new_folder_name, file_path)
#     101
# --> 102
#     103
#
# FileExistsError: [Errno 17] File exists: 'pictures/99'
#
# During handling of the above exception, another exception occurred:
#
# FileExistsError                           Traceback (most recent call last)
# ~/parser/ALIBABA_PARSER.py in photo_downloader(self, link_quantity, new_folder_name, file_path)
#     101
# --> 102
#     103
#
# FileExistsError: [Errno 17] File exists: 'pictures/100'
#
# During handling of the above exception, another exception occurred:
#
# FileExistsError                           Traceback (most recent call last)
# ~/parser/ALIBABA_PARSER.py in photo_downloader(self, link_quantity, new_folder_name, file_path)
#     101
# --> 102
#     103
#
# FileExistsError: [Errno 17] File exists: 'pictures/101'
#
# During handling of the above exception, another exception occurred:
#
# FileExistsError                           Traceback (most recent call last)
# ~/parser/ALIBABA_PARSER.py in photo_downloader(self, link_quantity, new_folder_name, file_path)
#     101
# --> 102
#     103
#
# FileExistsError: [Errno 17] File exists: 'pictures/102'
#
# During handling of the above exception, another exception occurred:
#
# FileExistsError                           Traceback (most recent call last)
# ~/parser/ALIBABA_PARSER.py in photo_downloader(self, link_quantity, new_folder_name, file_path)
#     101
# --> 102
#     103
#
# FileExistsError: [Errno 17] File exists: 'pictures/103'
#
# During handling of the above exception, another exception occurred:
#
# FileExistsError                           Traceback (most recent call last)
# ~/parser/ALIBABA_PARSER.py in photo_downloader(self, link_quantity, new_folder_name, file_path)
#     101
# --> 102
#     103
#
# FileExistsError: [Errno 17] File exists: 'pictures/104'
#
# During handling of the above exception, another exception occurred:
#
# FileExistsError                           Traceback (most recent call last)
# ~/parser/ALIBABA_PARSER.py in photo_downloader(self, link_quantity, new_folder_name, file_path)
#     101
# --> 102
#     103
#
# FileExistsError: [Errno 17] File exists: 'pictures/105'
#
# During handling of the above exception, another exception occurred:
#
# FileExistsError                           Traceback (most recent call last)
# ~/parser/ALIBABA_PARSER.py in photo_downloader(self, link_quantity, new_folder_name, file_path)
#     101
# --> 102
#     103
#
# FileExistsError: [Errno 17] File exists: 'pictures/106'
#
# During handling of the above exception, another exception occurred:
#
# FileExistsError                           Traceback (most recent call last)
# ~/parser/ALIBABA_PARSER.py in photo_downloader(self, link_quantity, new_folder_name, file_path)
#     101
# --> 102
#     103
#
# FileExistsError: [Errno 17] File exists: 'pictures/107'
#
# During handling of the above exception, another exception occurred:
#
# FileExistsError                           Traceback (most recent call last)
# ~/parser/ALIBABA_PARSER.py in photo_downloader(self, link_quantity, new_folder_name, file_path)
#     101
# --> 102
#     103
#
# FileExistsError: [Errno 17] File exists: 'pictures/108'
#
# During handling of the above exception, another exception occurred:
#
# FileExistsError                           Traceback (most recent call last)
# ~/parser/ALIBABA_PARSER.py in photo_downloader(self, link_quantity, new_folder_name, file_path)
#     101
# --> 102
#     103
#
# FileExistsError: [Errno 17] File exists: 'pictures/109'
#
# During handling of the above exception, another exception occurred:
#
# FileExistsError                           Traceback (most recent call last)
# ~/parser/ALIBABA_PARSER.py in photo_downloader(self, link_quantity, new_folder_name, file_path)
#     101
# --> 102
#     103
#
# FileExistsError: [Errno 17] File exists: 'pictures/110'
#
# During handling of the above exception, another exception occurred:
#
# FileExistsError                           Traceback (most recent call last)
# ~/parser/ALIBABA_PARSER.py in photo_downloader(self, link_quantity, new_folder_name, file_path)
#     101
# --> 102
#     103
#
# FileExistsError: [Errno 17] File exists: 'pictures/111'
#
# During handling of the above exception, another exception occurred:
#
# FileExistsError                           Traceback (most recent call last)
# ~/parser/ALIBABA_PARSER.py in photo_downloader(self, link_quantity, new_folder_name, file_path)
#     101
# --> 102
#     103
#
# FileExistsError: [Errno 17] File exists: 'pictures/112'
#
# During handling of the above exception, another exception occurred:
#
# FileExistsError                           Traceback (most recent call last)
# ~/parser/ALIBABA_PARSER.py in photo_downloader(self, link_quantity, new_folder_name, file_path)
#     101
# --> 102
#     103
#
# FileExistsError: [Errno 17] File exists: 'pictures/113'
#
# During handling of the above exception, another exception occurred:
#
# FileExistsError                           Traceback (most recent call last)
# ~/parser/ALIBABA_PARSER.py in photo_downloader(self, link_quantity, new_folder_name, file_path)
#     101
# --> 102
#     103
#
# FileExistsError: [Errno 17] File exists: 'pictures/114'
#
# During handling of the above exception, another exception occurred:
#
# FileExistsError                           Traceback (most recent call last)
# ~/parser/ALIBABA_PARSER.py in photo_downloader(self, link_quantity, new_folder_name, file_path)
#     101
# --> 102
#     103
#
# FileExistsError: [Errno 17] File exists: 'pictures/115'
#
# During handling of the above exception, another exception occurred:
#
# FileExistsError                           Traceback (most recent call last)
# ~/parser/ALIBABA_PARSER.py in photo_downloader(self, link_quantity, new_folder_name, file_path)
#     101
# --> 102
#     103
#
# FileExistsError: [Errno 17] File exists: 'pictures/116'
#
# During handling of the above exception, another exception occurred:
#
# FileExistsError                           Traceback (most recent call last)
# ~/parser/ALIBABA_PARSER.py in photo_downloader(self, link_quantity, new_folder_name, file_path)
#     101
# --> 102
#     103
#
# FileExistsError: [Errno 17] File exists: 'pictures/117'
#
# During handling of the above exception, another exception occurred:
#
# FileExistsError                           Traceback (most recent call last)
# ~/parser/ALIBABA_PARSER.py in photo_downloader(self, link_quantity, new_folder_name, file_path)
#     101
# --> 102
#     103
#
# FileExistsError: [Errno 17] File exists: 'pictures/118'
#
# During handling of the above exception, another exception occurred:
#
# FileExistsError                           Traceback (most recent call last)
# ~/parser/ALIBABA_PARSER.py in photo_downloader(self, link_quantity, new_folder_name, file_path)
#     101
# --> 102
#     103
#
# FileExistsError: [Errno 17] File exists: 'pictures/119'
#
# During handling of the above exception, another exception occurred:
#
# FileExistsError                           Traceback (most recent call last)
# ~/parser/ALIBABA_PARSER.py in photo_downloader(self, link_quantity, new_folder_name, file_path)
#     101
# --> 102
#     103
#
# FileExistsError: [Errno 17] File exists: 'pictures/120'
#
# During handling of the above exception, another exception occurred:
#
# FileExistsError                           Traceback (most recent call last)
# ~/parser/ALIBABA_PARSER.py in photo_downloader(self, link_quantity, new_folder_name, file_path)
#     101
# --> 102
#     103
#
# FileExistsError: [Errno 17] File exists: 'pictures/121'
#
# During handling of the above exception, another exception occurred:
#
# FileExistsError                           Traceback (most recent call last)
# ~/parser/ALIBABA_PARSER.py in photo_downloader(self, link_quantity, new_folder_name, file_path)
#     101
# --> 102
#     103
#
# FileExistsError: [Errno 17] File exists: 'pictures/122'
#
# During handling of the above exception, another exception occurred:
#
# FileExistsError                           Traceback (most recent call last)
# ~/parser/ALIBABA_PARSER.py in photo_downloader(self, link_quantity, new_folder_name, file_path)
#     101
# --> 102
#     103
#
# FileExistsError: [Errno 17] File exists: 'pictures/123'
#
# During handling of the above exception, another exception occurred:
#
# FileExistsError                           Traceback (most recent call last)
# ~/parser/ALIBABA_PARSER.py in photo_downloader(self, link_quantity, new_folder_name, file_path)
#     101
# --> 102
#     103
#
# FileExistsError: [Errno 17] File exists: 'pictures/124'
#
# During handling of the above exception, another exception occurred:
#
# FileExistsError                           Traceback (most recent call last)
# ~/parser/ALIBABA_PARSER.py in photo_downloader(self, link_quantity, new_folder_name, file_path)
#     101
# --> 102
#     103
#
# FileExistsError: [Errno 17] File exists: 'pictures/125'
#
# During handling of the above exception, another exception occurred:
#
# FileExistsError                           Traceback (most recent call last)
# ~/parser/ALIBABA_PARSER.py in photo_downloader(self, link_quantity, new_folder_name, file_path)
#     101
# --> 102
#     103
#
# FileExistsError: [Errno 17] File exists: 'pictures/126'
#
# During handling of the above exception, another exception occurred:
#
# FileExistsError                           Traceback (most recent call last)
# ~/parser/ALIBABA_PARSER.py in photo_downloader(self, link_quantity, new_folder_name, file_path)
#     101
# --> 102
#     103
#
# FileExistsError: [Errno 17] File exists: 'pictures/127'
#
# During handling of the above exception, another exception occurred:
#
# FileExistsError                           Traceback (most recent call last)
# ~/parser/ALIBABA_PARSER.py in photo_downloader(self, link_quantity, new_folder_name, file_path)
#     101
# --> 102
#     103
#
# FileExistsError: [Errno 17] File exists: 'pictures/128'
#
# During handling of the above exception, another exception occurred:
#
# FileExistsError                           Traceback (most recent call last)
# ~/parser/ALIBABA_PARSER.py in photo_downloader(self, link_quantity, new_folder_name, file_path)
#     101
# --> 102
#     103
#
# FileExistsError: [Errno 17] File exists: 'pictures/129'
#
# During handling of the above exception, another exception occurred:
#
# FileExistsError                           Traceback (most recent call last)
# ~/parser/ALIBABA_PARSER.py in photo_downloader(self, link_quantity, new_folder_name, file_path)
#     101
# --> 102
#     103
#
# FileExistsError: [Errno 17] File exists: 'pictures/130'
#
# During handling of the above exception, another exception occurred:
#
# FileExistsError                           Traceback (most recent call last)
# ~/parser/ALIBABA_PARSER.py in photo_downloader(self, link_quantity, new_folder_name, file_path)
#     101
# --> 102
#     103
#
# FileExistsError: [Errno 17] File exists: 'pictures/131'
#
# During handling of the above exception, another exception occurred:
#
# FileExistsError                           Traceback (most recent call last)
# ~/parser/ALIBABA_PARSER.py in photo_downloader(self, link_quantity, new_folder_name, file_path)
#     101
# --> 102
#     103
#
# FileExistsError: [Errno 17] File exists: 'pictures/132'
#
# During handling of the above exception, another exception occurred:
#
# FileExistsError                           Traceback (most recent call last)
# ~/parser/ALIBABA_PARSER.py in photo_downloader(self, link_quantity, new_folder_name, file_path)
#     101
# --> 102
#     103
#
# FileExistsError: [Errno 17] File exists: 'pictures/133'
#
# During handling of the above exception, another exception occurred:
#
# FileExistsError                           Traceback (most recent call last)
# ~/parser/ALIBABA_PARSER.py in photo_downloader(self, link_quantity, new_folder_name, file_path)
#     101
# --> 102
#     103
#
# FileExistsError: [Errno 17] File exists: 'pictures/134'
#
# During handling of the above exception, another exception occurred:
#
# FileExistsError                           Traceback (most recent call last)
# ~/parser/ALIBABA_PARSER.py in photo_downloader(self, link_quantity, new_folder_name, file_path)
#     101
# --> 102
#     103
#
# FileExistsError: [Errno 17] File exists: 'pictures/135'
#
# During handling of the above exception, another exception occurred:
#
# FileExistsError                           Traceback (most recent call last)
# ~/parser/ALIBABA_PARSER.py in photo_downloader(self, link_quantity, new_folder_name, file_path)
#     101
# --> 102
#     103
#
# FileExistsError: [Errno 17] File exists: 'pictures/136'
#
# During handling of the above exception, another exception occurred:
#
# FileExistsError                           Traceback (most recent call last)
# ~/parser/ALIBABA_PARSER.py in photo_downloader(self, link_quantity, new_folder_name, file_path)
#     101
# --> 102
#     103
#
# FileExistsError: [Errno 17] File exists: 'pictures/137'
#
# During handling of the above exception, another exception occurred:
#
# FileExistsError                           Traceback (most recent call last)
# ~/parser/ALIBABA_PARSER.py in photo_downloader(self, link_quantity, new_folder_name, file_path)
#     101
# --> 102
#     103
#
# FileExistsError: [Errno 17] File exists: 'pictures/138'
#
# During handling of the above exception, another exception occurred:
#
# FileExistsError                           Traceback (most recent call last)
# ~/parser/ALIBABA_PARSER.py in photo_downloader(self, link_quantity, new_folder_name, file_path)
#     101
# --> 102
#     103
#
# FileExistsError: [Errno 17] File exists: 'pictures/139'
#
# During handling of the above exception, another exception occurred:
#
# FileExistsError                           Traceback (most recent call last)
# ~/parser/ALIBABA_PARSER.py in photo_downloader(self, link_quantity, new_folder_name, file_path)
#     101
# --> 102
#     103
#
# FileExistsError: [Errno 17] File exists: 'pictures/140'
#
# During handling of the above exception, another exception occurred:
#
# FileExistsError                           Traceback (most recent call last)
# ~/parser/ALIBABA_PARSER.py in photo_downloader(self, link_quantity, new_folder_name, file_path)
#     101
# --> 102
#     103
#
# FileExistsError: [Errno 17] File exists: 'pictures/141'
#
# During handling of the above exception, another exception occurred:
#
# FileExistsError                           Traceback (most recent call last)
# ~/parser/ALIBABA_PARSER.py in photo_downloader(self, link_quantity, new_folder_name, file_path)
#     101
# --> 102
#     103
#
# FileExistsError: [Errno 17] File exists: 'pictures/142'
#
# During handling of the above exception, another exception occurred:
#
# FileExistsError                           Traceback (most recent call last)
# ~/parser/ALIBABA_PARSER.py in photo_downloader(self, link_quantity, new_folder_name, file_path)
#     101
# --> 102
#     103
#
# FileExistsError: [Errno 17] File exists: 'pictures/143'
#
# During handling of the above exception, another exception occurred:
#
# FileExistsError                           Traceback (most recent call last)
# ~/parser/ALIBABA_PARSER.py in photo_downloader(self, link_quantity, new_folder_name, file_path)
#     101
# --> 102
#     103
#
# FileExistsError: [Errno 17] File exists: 'pictures/144'
#
# During handling of the above exception, another exception occurred:
#
# FileExistsError                           Traceback (most recent call last)
# ~/parser/ALIBABA_PARSER.py in photo_downloader(self, link_quantity, new_folder_name, file_path)
#     101
# --> 102
#     103
#
# FileExistsError: [Errno 17] File exists: 'pictures/145'
#
# During handling of the above exception, another exception occurred:
#
# FileExistsError                           Traceback (most recent call last)
# ~/parser/ALIBABA_PARSER.py in photo_downloader(self, link_quantity, new_folder_name, file_path)
#     101
# --> 102
#     103
#
# FileExistsError: [Errno 17] File exists: 'pictures/146'
#
# During handling of the above exception, another exception occurred:
#
# ...
#     104     def photo_downloader(self,
#     105                          link_quantity=50,
# --> 106                          new_folder_name=0,
#     107                          file_path='true_urls/urls.txt'):
#     108
#
# ~/parser/ALIBABA_PARSER.py in photo_downloader(self, link_quantity, new_folder_name, file_path)
#     104     def photo_downloader(self,
#     105                          link_quantity=50,
# --> 106                          new_folder_name=0,
#     107                          file_path='true_urls/urls.txt'):
#     108
#
# ~/parser/ALIBABA_PARSER.py in photo_downloader(self, link_quantity, new_folder_name, file_path)
#     104     def photo_downloader(self,
#     105                          link_quantity=50,
# --> 106                          new_folder_name=0,
#     107                          file_path='true_urls/urls.txt'):
#     108
#
# ~/parser/ALIBABA_PARSER.py in photo_downloader(self, link_quantity, new_folder_name, file_path)
#     104     def photo_downloader(self,
#     105                          link_quantity=50,
# --> 106                          new_folder_name=0,
#     107                          file_path='true_urls/urls.txt'):
#     108
#
# ~/parser/ALIBABA_PARSER.py in photo_downloader(self, link_quantity, new_folder_name, file_path)
#     104     def photo_downloader(self,
#     105                          link_quantity=50,
# --> 106                          new_folder_name=0,
#     107                          file_path='true_urls/urls.txt'):
#     108
#
# ~/parser/ALIBABA_PARSER.py in photo_downloader(self, link_quantity, new_folder_name, file_path)
#     104     def photo_downloader(self,
#     105                          link_quantity=50,
# --> 106                          new_folder_name=0,
#     107                          file_path='true_urls/urls.txt'):
#     108
#
# ~/parser/ALIBABA_PARSER.py in photo_downloader(self, link_quantity, new_folder_name, file_path)
#     104     def photo_downloader(self,
#     105                          link_quantity=50,
# --> 106                          new_folder_name=0,
#     107                          file_path='true_urls/urls.txt'):
#     108
#
# ~/parser/ALIBABA_PARSER.py in photo_downloader(self, link_quantity, new_folder_name, file_path)
#     104     def photo_downloader(self,
#     105                          link_quantity=50,
# --> 106                          new_folder_name=0,
#     107                          file_path='true_urls/urls.txt'):
#     108
#
# ~/parser/ALIBABA_PARSER.py in photo_downloader(self, link_quantity, new_folder_name, file_path)
#     104     def photo_downloader(self,
#     105                          link_quantity=50,
# --> 106                          new_folder_name=0,
#     107                          file_path='true_urls/urls.txt'):
#     108
#
# ~/parser/ALIBABA_PARSER.py in photo_downloader(self, link_quantity, new_folder_name, file_path)
#     104     def photo_downloader(self,
#     105                          link_quantity=50,
# --> 106                          new_folder_name=0,
#     107                          file_path='true_urls/urls.txt'):
#     108
#
# ~/parser/ALIBABA_PARSER.py in photo_downloader(self, link_quantity, new_folder_name, file_path)
#     104     def photo_downloader(self,
#     105                          link_quantity=50,
# --> 106                          new_folder_name=0,
#     107                          file_path='true_urls/urls.txt'):
#     108
#
# ~/parser/ALIBABA_PARSER.py in photo_downloader(self, link_quantity, new_folder_name, file_path)
#     104     def photo_downloader(self,
#     105                          link_quantity=50,
# --> 106                          new_folder_name=0,
#     107                          file_path='true_urls/urls.txt'):
#     108
#
# ~/parser/ALIBABA_PARSER.py in photo_downloader(self, link_quantity, new_folder_name, file_path)
#     104     def photo_downloader(self,
#     105                          link_quantity=50,
# --> 106                          new_folder_name=0,
#     107                          file_path='true_urls/urls.txt'):
#     108
#
# ~/parser/ALIBABA_PARSER.py in photo_downloader(self, link_quantity, new_folder_name, file_path)
#     104     def photo_downloader(self,
#     105                          link_quantity=50,
# --> 106                          new_folder_name=0,
#     107                          file_path='true_urls/urls.txt'):
#     108
#
# ~/parser/ALIBABA_PARSER.py in photo_downloader(self, link_quantity, new_folder_name, file_path)
#     104     def photo_downloader(self,
#     105                          link_quantity=50,
# --> 106                          new_folder_name=0,
#     107                          file_path='true_urls/urls.txt'):
#     108
#
# ~/parser/ALIBABA_PARSER.py in photo_downloader(self, link_quantity, new_folder_name, file_path)
#     104     def photo_downloader(self,
#     105                          link_quantity=50,
# --> 106                          new_folder_name=0,
#     107                          file_path='true_urls/urls.txt'):
#     108
#
# ~/parser/ALIBABA_PARSER.py in photo_downloader(self, link_quantity, new_folder_name, file_path)
#     104     def photo_downloader(self,
#     105                          link_quantity=50,
# --> 106                          new_folder_name=0,
#     107                          file_path='true_urls/urls.txt'):
#     108
#
# ~/parser/ALIBABA_PARSER.py in photo_downloader(self, link_quantity, new_folder_name, file_path)
#     104     def photo_downloader(self,
#     105                          link_quantity=50,
# --> 106                          new_folder_name=0,
#     107                          file_path='true_urls/urls.txt'):
#     108
#
# ~/parser/ALIBABA_PARSER.py in photo_downloader(self, link_quantity, new_folder_name, file_path)
#     104     def photo_downloader(self,
#     105                          link_quantity=50,
# --> 106                          new_folder_name=0,
#     107                          file_path='true_urls/urls.txt'):
#     108
#
# ~/parser/ALIBABA_PARSER.py in photo_downloader(self, link_quantity, new_folder_name, file_path)
#     104     def photo_downloader(self,
#     105                          link_quantity=50,
# --> 106                          new_folder_name=0,
#     107                          file_path='true_urls/urls.txt'):
#     108
#
# ~/parser/ALIBABA_PARSER.py in photo_downloader(self, link_quantity, new_folder_name, file_path)
#     104     def photo_downloader(self,
#     105                          link_quantity=50,
# --> 106                          new_folder_name=0,
#     107                          file_path='true_urls/urls.txt'):
#     108
#
# ~/parser/ALIBABA_PARSER.py in photo_downloader(self, link_quantity, new_folder_name, file_path)
#     104     def photo_downloader(self,
#     105                          link_quantity=50,
# --> 106                          new_folder_name=0,
#     107                          file_path='true_urls/urls.txt'):
#     108
#
# ~/parser/ALIBABA_PARSER.py in photo_downloader(self, link_quantity, new_folder_name, file_path)
#     104     def photo_downloader(self,
#     105                          link_quantity=50,
# --> 106                          new_folder_name=0,
#     107                          file_path='true_urls/urls.txt'):
#     108
#
# ~/parser/ALIBABA_PARSER.py in photo_downloader(self, link_quantity, new_folder_name, file_path)
#     104     def photo_downloader(self,
#     105                          link_quantity=50,
# --> 106                          new_folder_name=0,
#     107                          file_path='true_urls/urls.txt'):
#     108
#
# ~/parser/ALIBABA_PARSER.py in photo_downloader(self, link_quantity, new_folder_name, file_path)
#     104     def photo_downloader(self,
#     105                          link_quantity=50,
# --> 106                          new_folder_name=0,
#     107                          file_path='true_urls/urls.txt'):
#     108
#
# ~/parser/ALIBABA_PARSER.py in photo_downloader(self, link_quantity, new_folder_name, file_path)
#     104     def photo_downloader(self,
#     105                          link_quantity=50,
# --> 106                          new_folder_name=0,
#     107                          file_path='true_urls/urls.txt'):
#     108
#
# ~/parser/ALIBABA_PARSER.py in photo_downloader(self, link_quantity, new_folder_name, file_path)
#     104     def photo_downloader(self,
#     105                          link_quantity=50,
# --> 106                          new_folder_name=0,
#     107                          file_path='true_urls/urls.txt'):
#     108
#
# ~/parser/ALIBABA_PARSER.py in photo_downloader(self, link_quantity, new_folder_name, file_path)
#     104     def photo_downloader(self,
#     105                          link_quantity=50,
# --> 106                          new_folder_name=0,
#     107                          file_path='true_urls/urls.txt'):
#     108
#
# ~/parser/ALIBABA_PARSER.py in photo_downloader(self, link_quantity, new_folder_name, file_path)
#     104     def photo_downloader(self,
#     105                          link_quantity=50,
# --> 106                          new_folder_name=0,
#     107                          file_path='true_urls/urls.txt'):
#     108
#
# ~/parser/ALIBABA_PARSER.py in photo_downloader(self, link_quantity, new_folder_name, file_path)
#     104     def photo_downloader(self,
#     105                          link_quantity=50,
# --> 106                          new_folder_name=0,
#     107                          file_path='true_urls/urls.txt'):
#     108
#
# ~/parser/ALIBABA_PARSER.py in photo_downloader(self, link_quantity, new_folder_name, file_path)
#     104     def photo_downloader(self,
#     105                          link_quantity=50,
# --> 106                          new_folder_name=0,
#     107                          file_path='true_urls/urls.txt'):
#     108
#
# ~/parser/ALIBABA_PARSER.py in photo_downloader(self, link_quantity, new_folder_name, file_path)
#     104     def photo_downloader(self,
#     105                          link_quantity=50,
# --> 106                          new_folder_name=0,
#     107                          file_path='true_urls/urls.txt'):
#     108
#
# ~/parser/ALIBABA_PARSER.py in photo_downloader(self, link_quantity, new_folder_name, file_path)
#     104     def photo_downloader(self,
#     105                          link_quantity=50,
# --> 106                          new_folder_name=0,
#     107                          file_path='true_urls/urls.txt'):
#     108
#
# ~/parser/ALIBABA_PARSER.py in photo_downloader(self, link_quantity, new_folder_name, file_path)
#     104     def photo_downloader(self,
#     105                          link_quantity=50,
# --> 106                          new_folder_name=0,
#     107                          file_path='true_urls/urls.txt'):
#     108
#
# ~/parser/ALIBABA_PARSER.py in photo_downloader(self, link_quantity, new_folder_name, file_path)
#     154         elements=[element for element in self.driver.find_elements(By.TAG_NAME, 'img') if element.get_attribute('loading')=="lazy"]
#     155         srcs=[element.get_attribute('src') for element in elements if element.get_attribute('src')]
# --> 156         srcs=srcs[::-1]
#     157         srcs=srcs[len(photo_elements):len(photo_elements)*2]
#     158
#
# ~/parser/ALIBABA_PARSER.py in photo_downloader(self, link_quantity, new_folder_name, file_path)
#     113
#     114
# --> 115         #create index + 1 folder
#     116         try:
#     117             mkdir(f"pictures/{new_folder_name}")
#
# ~/anaconda3/envs/scrap/lib/python3.7/site-packages/selenium/webdriver/remote/webdriver.py in get(self, url)
#     352     def get(self, url: str) -> None:
#     353         """Loads a web page in the current browser session."""
# --> 354         self.execute(Command.GET, {"url": url})
#     355
#     356     @property
#
# ~/anaconda3/envs/scrap/lib/python3.7/site-packages/selenium/webdriver/remote/webdriver.py in execute(self, driver_command, params)
#     341                 params["sessionId"] = self.session_id
#     342
# --> 343         response = self.command_executor.execute(driver_command, params)
#     344         if response:
#     345             self.error_handler.check_response(response)
#
# ~/anaconda3/envs/scrap/lib/python3.7/site-packages/selenium/webdriver/remote/remote_connection.py in execute(self, command, params)
#     289         data = utils.dump_json(params)
#     290         url = f"{self._url}{path}"
# --> 291         return self._request(command_info[0], url, body=data)
#     292
#     293     def _request(self, method, url, body=None):
#
# ~/anaconda3/envs/scrap/lib/python3.7/site-packages/selenium/webdriver/remote/remote_connection.py in _request(self, method, url, body)
#     310
#     311         if self.keep_alive:
# --> 312             response = self._conn.request(method, url, body=body, headers=headers)
#     313             statuscode = response.status
#     314         else:
#
# ~/anaconda3/envs/scrap/lib/python3.7/site-packages/urllib3/_request_methods.py in request(self, method, url, body, fields, headers, json, **urlopen_kw)
#     117         else:
#     118             return self.request_encode_body(
# --> 119                 method, url, fields=fields, headers=headers, **urlopen_kw
#     120             )
#     121
#
# ~/anaconda3/envs/scrap/lib/python3.7/site-packages/urllib3/_request_methods.py in request_encode_body(self, method, url, fields, headers, encode_multipart, multipart_boundary, **urlopen_kw)
#     215         extra_kw.update(urlopen_kw)
#     216
# --> 217         return self.urlopen(method, url, **extra_kw)
#
# ~/anaconda3/envs/scrap/lib/python3.7/site-packages/urllib3/poolmanager.py in urlopen(self, method, url, redirect, **kw)
#     441             response = conn.urlopen(method, url, **kw)
#     442         else:
# --> 443             response = conn.urlopen(method, u.request_uri, **kw)
#     444
#     445         redirect_location = redirect and response.get_redirect_location()
#
# ~/anaconda3/envs/scrap/lib/python3.7/site-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     800                 preload_content=preload_content,
#     801                 decode_content=decode_content,
# --> 802                 **response_kw,
#     803             )
#     804
#
# ~/anaconda3/envs/scrap/lib/python3.7/site-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     534         # Receive the response from the server
#     535         try:
# --> 536             response = conn.getresponse()
#     537         except (BaseSSLError, OSError) as e:
#     538             self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#
# ~/anaconda3/envs/scrap/lib/python3.7/site-packages/urllib3/connection.py in getresponse(self)
#     459
#     460         # Get the response from http.client.HTTPConnection
# --> 461         httplib_response = super().getresponse()
#     462
#     463         try:
#
# ~/anaconda3/envs/scrap/lib/python3.7/http/client.py in getresponse(self)
#    1371         try:
#    1372             try:
# -> 1373                 response.begin()
#    1374             except ConnectionError:
#    1375                 self.close()
#
# ~/anaconda3/envs/scrap/lib/python3.7/http/client.py in begin(self)
#     317         # read until we get a non-100 response
#     318         while True:
# --> 319             version, status, reason = self._read_status()
#     320             if status != CONTINUE:
#     321                 break
#
# ~/anaconda3/envs/scrap/lib/python3.7/http/client.py in _read_status(self)
#     278
#     279     def _read_status(self):
# --> 280         line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     281         if len(line) > _MAXLINE:
#     282             raise LineTooLong("status line")
#
# ~/anaconda3/envs/scrap/lib/python3.7/socket.py in readinto(self, b)
#     587         while True:
#     588             try:
# --> 589                 return self._sock.recv_into(b)
#     590             except timeout:
#     591                 self._timeout_occurred = True
#
# KeyboardInterrupt:
